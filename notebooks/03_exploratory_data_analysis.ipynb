# %%
import pandas as pd
# Importar las librerÃ­as necesarias
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report, confusion_matrix

# %%
df = pd.read_csv('../data/raw/bank_data.csv', sep=";")

# %% [markdown]
# ## Limpieza

# %%
print(df.head())


print(df.info())


print(df.describe())
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# ...

# %% [markdown]
# #### Analisis de nulos

# %%
print(df.isnull().sum())
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %% [markdown]
# ### Analisis de Duplicados

# %%
print(df.duplicated().value_counts())
# Out:
# False    45211
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# GrÃ¡fico de distribuciÃ³n para detectar posibles outliers en la columna balance
sns.boxplot(x=df['balance'])
plt.show()

# GrÃ¡fico de distribuciÃ³n para la duraciÃ³n de la llamada
sns.boxplot(x=df['duration'])
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Cargar los datos
df = pd.read_csv('../data/raw/bank_data.csv', sep=';')

# Convertir la variable objetivo a numÃ©rica
df['y'] = df['y'].map({'no': 0, 'yes': 1})

# Crear una nueva columna para agrupar por rangos de edad
bins = [18, 26, 66, 96]
labels = ['18-25', '26-65', '66-95']
df['age_group'] = pd.cut(df['age'], bins=bins, labels=labels, right=False)

# Calcular el conteo de suscripciones por grupo de edad
age_counts = df.groupby(['age_group', 'y']).size().unstack(fill_value=0)

# Calcular el porcentaje de suscripciones
age_counts['Total'] = age_counts.sum(axis=1)
age_counts['SuscripciÃ³n (%)'] = (age_counts[1] / age_counts['Total']) * 100

# Crear la grÃ¡fica de barras para porcentajes
plt.figure(figsize=(12, 6))
sns.barplot(x=age_counts.index, y=age_counts['SuscripciÃ³n (%)'])

plt.title('Porcentaje de Suscripciones a DepÃ³sitos a Plazo por Grupo de Edad')
plt.xlabel('Grupo de Edad')
plt.ylabel('Porcentaje de SuscripciÃ³n (%)')
plt.ylim(0, 100)
plt.xticks(rotation=45)

# AÃ±adir etiquetas de porcentaje encima de las barras
for index, value in enumerate(age_counts['SuscripciÃ³n (%)']):
    plt.text(index, value + 2, f"{value:.2f}%", ha='center', va='bottom')

plt.grid(axis='y')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\aleja\AppData\Local\Temp\ipykernel_77152\1713754198.py:17: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   age_counts = df.groupby(['age_group', 'y']).size().unstack(fill_value=0)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargar los datos
df = pd.read_csv('../data/raw/bank_data.csv', sep=';')

# Convertir la variable objetivo a numÃ©rica
df['y'] = df['y'].map({'no': 0, 'yes': 1})

# Calcular el conteo de suscripciones por nivel educativo
education_counts = df.groupby(['education', 'y']).size().unstack(fill_value=0)

# Calcular el porcentaje de suscripciones
education_counts['Total'] = education_counts.sum(axis=1)
education_counts['SuscripciÃ³n (%)'] = (education_counts[1] / education_counts['Total']) * 100

# Crear la grÃ¡fica de barras
plt.figure(figsize=(12, 6))
plt.bar(education_counts.index, education_counts['SuscripciÃ³n (%)'], color='lightblue')

plt.title('Porcentaje de Suscripciones a DepÃ³sitos a Plazo por Nivel Educativo')
plt.xlabel('Nivel Educativo')
plt.ylabel('Porcentaje de SuscripciÃ³n (%)')
plt.ylim(0, 100)
plt.xticks(rotation=45)
plt.grid(axis='y')

# AÃ±adir etiquetas de porcentaje encima de las barras
for index, value in enumerate(education_counts['SuscripciÃ³n (%)']):
    plt.text(index, value + 2, f"{value:.2f}%", ha='center', va='bottom')

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargar los datos
df = pd.read_csv('../data/raw/bank_data.csv', sep=';')

# Convertir la variable objetivo a numÃ©rica
df['y'] = df['y'].map({'no': 0, 'yes': 1})

# Calcular el conteo de suscripciones por estado civil
marital_counts = df.groupby('marital')['y'].value_counts().unstack(fill_value=0)

# Calcular el porcentaje de suscripciones
marital_counts['Total'] = marital_counts.sum(axis=1)
marital_counts['SuscripciÃ³n (%)'] = (marital_counts[1] / marital_counts['Total']) * 100

# Crear la grÃ¡fica de barras
plt.figure(figsize=(10, 6))
plt.bar(marital_counts.index, marital_counts['SuscripciÃ³n (%)'], color='lightblue')

plt.title('Porcentaje de Suscripciones a DepÃ³sitos a Plazo por Estado Civil')
plt.xlabel('Estado Civil')
plt.ylabel('Porcentaje de SuscripciÃ³n (%)')
plt.ylim(0, 100)
plt.xticks(rotation=0)
plt.grid(axis='y')

# AÃ±adir etiquetas de porcentaje encima de las barras
for index, value in enumerate(marital_counts['SuscripciÃ³n (%)']):
    plt.text(index, value + 2, f"{value:.2f}%", ha='center', va='bottom')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Analisis de Datos

# %%
# AsegÃºrate de que 'y' tenga valores 'No' y 'SÃ­' en lugar de 0 y 1
df['y'] = df['y'].replace({0: 'No', 1: 'SÃ­'})

# GrÃ¡fico de dispersiÃ³n
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='balance', y='duration', hue='y', palette='RdPu')
plt.title('RelaciÃ³n entre Balance y DuraciÃ³n de la Llamada')
plt.xlabel('Balance')
plt.ylabel('DuraciÃ³n de la Llamada')
plt.legend(title='SuscripciÃ³n')
plt.show()

# %%
df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  No
# 1  unknown    5   may       151         1     -1         0  unknown  No
# 2  unknown    5   may        76         1     -1         0  unknown  No
# 3  unknown    5   may        92         1     -1         0  unknown  No
# 4  unknown    5   may       198         1     -1         0  unknown  No

# %%
df.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.936210    1362.272058     15.806419    258.163080      2.763841
# std       10.618762    3044.765829      8.322476    257.527812      3.098021
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %%
df[['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'poutcome']].value_counts()
# Out:
# job            marital  education  default  housing  loan  contact    month  poutcome
# blue-collar    married  secondary  no       yes      no    unknown    may    unknown     750
# management     married  tertiary   no       no       no    cellular   aug    unknown     705
# blue-collar    married  primary    no       yes      no    unknown    may    unknown     657
# technician     married  secondary  no       no       no    cellular   aug    unknown     439
# management     single   tertiary   no       no       no    cellular   aug    unknown     385
#                                                                                         ...
# self-employed  married  tertiary   no       yes      yes   cellular   apr    failure       1
# entrepreneur   married  tertiary   no       no       yes   telephone  jul    unknown       1
# self-employed  married  tertiary   no       yes      yes   cellular   feb    unknown       1
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# SelecciÃ³n de variables numÃ©ricas para la matriz de correlaciÃ³n
numeric_vars = df.select_dtypes(include='number')

# CÃ¡lculo de la matriz de correlaciÃ³n
correlation_matrix = numeric_vars.corr()

# ConfiguraciÃ³n de la visualizaciÃ³n
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap="RdPu", center=0, linewidths=1, linecolor='white', fmt=".2f")
plt.title("Matriz de CorrelaciÃ³n")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Filtrar los datos para enfocarse solo en "SÃ­"
df_si = df[df['y'] == 'SÃ­']

# Definir las variables de entrada (nombres de las columnas que mencionaste)
variables_entrada = ['age', 'job', 'marital', 'education', 'default', 'balance', 'housing', 'loan', 
                     'contact', 'day', 'month', 'duration', 'campaign', 'pdays', 'previous']

# Configurar el tamaÃ±o de la figura
plt.figure(figsize=(25, 20))

# Crear una grÃ¡fica por cada variable de entrada
for i, columna in enumerate(variables_entrada):
    plt.subplot(5, 4, i+1)
    if df_si[columna].dtype == 'O':  # Si es categÃ³rica
        sns.countplot(x=columna, data=df_si, color='#8644A2')
    else:  # Si es numÃ©rica
        sns.histplot(x=columna, data=df_si, bins=30, color='#8644A2')
    
    plt.title(f'RelaciÃ³n con y (SÃ­): {columna}')
    plt.xlabel(columna)
    plt.ylabel('Frecuencia')

# Ajustar el diseÃ±o de los subgrÃ¡ficos
plt.tight_layout()

# Mostrar las grÃ¡ficas
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(data=df, x='y', y='balance', palette="viridis")
plt.title("DistribuciÃ³n de Balance segÃºn SuscripciÃ³n a DepÃ³sito")
plt.xlabel("Â¿Ha suscrito un depÃ³sito?")
plt.ylabel("Balance")
plt.show()
# Out:
# C:\Users\aleja\AppData\Local\Temp\ipykernel_77152\3548088416.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='y', y='balance', palette="viridis")

# %%
import seaborn as sns
plt.figure(figsize=(12, 8))
sns.boxplot(data=df, x='y', y='balance')
# Out:
# <Axes: xlabel='y', ylabel='balance'>

# %%
plt.figure(figsize=(12, 8))
sns.violinplot(data=df, x='y', y='duration', palette="RdPu")
plt.title("DistribuciÃ³n de DuraciÃ³n de Contacto segÃºn SuscripciÃ³n a DepÃ³sito")
plt.xlabel("Â¿Ha suscrito un depÃ³sito?")
plt.ylabel("DuraciÃ³n (segundos)")
plt.show()
# Out:
# C:\Users\aleja\AppData\Local\Temp\ipykernel_77152\4157151456.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x='y', y='duration', palette="RdPu")

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Listas de variables de entrada numÃ©ricas y categÃ³ricas
numeric_vars = ['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous']
categorical_vars = ['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'poutcome']

# Histogramas para variables numÃ©ricas
for var in numeric_vars:
    plt.figure(figsize=(10, 5))
    sns.histplot(data=df, x=var, hue='y', multiple='stack', bins=30, palette=['#F075AA', '#8644A2'])
    plt.title(f'DistribuciÃ³n de {var} segÃºn la SuscripciÃ³n del DepÃ³sito')
    plt.xlabel(var)
    plt.ylabel('Frecuencia')
    plt.legend(title='SuscribiÃ³ DepÃ³sito', labels=['No', 'SÃ­'])
    plt.show()

# Para las variables categÃ³ricas, puedes hacer grÃ¡ficos de barras
for var in categorical_vars:
    plt.figure(figsize=(10, 5))
    sns.countplot(data=df, x=var, hue='y', palette=['#F075AA', '#8644A2'])
    plt.title(f'DistribuciÃ³n de {var} segÃºn la SuscripciÃ³n del DepÃ³sito')
    plt.xlabel(var)
    plt.ylabel('Frecuencia')
    plt.legend(title='SuscribiÃ³ DepÃ³sito', labels=['No', 'SÃ­'])
    plt.xticks(rotation=45)
    plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Definir las variables de entrada (nombres de las columnas que mencionaste)
variables_entrada = ['age', 'job', 'marital', 'education', 'default', 'balance', 'housing', 'loan', 
                     'contact', 'day', 'month', 'duration', 'campaign', 'pdays', 'previous']

# Configurar el tamaÃ±o de la figura
plt.figure(figsize=(25, 20))

# Crear una grÃ¡fica por cada variable de entrada
for i, columna in enumerate(variables_entrada):
    plt.subplot(5, 4, i+1)
    if df[columna].dtype == 'O':  # Si es categÃ³rica
        sns.countplot(x=columna, hue="y", data=df, palette=['#F075AA', '#8644A2'])
    else:  # Si es numÃ©rica
        sns.histplot(x=columna, hue="y", data=df, multiple='stack', bins=30, palette=['#F075AA', '#8644A2'])
    
    plt.title(f'RelaciÃ³n con y: {columna}')
    plt.xlabel(columna)
    plt.ylabel('Frecuencia')

# Ajustar el diseÃ±o de los subgrÃ¡ficos
plt.tight_layout()

# Mostrar las grÃ¡ficas
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import math

# Lista de variables numÃ©ricas para las que quieres crear boxplots
variables = ['age', 'balance', 'day', 'duration', 'campaign', 'previous']

# Calcular las filas y columnas necesarias para acomodar todas las variables
num_vars = len(variables)
cols = 2  # Puedes ajustarlo si deseas mÃ¡s columnas
rows = math.ceil(num_vars / cols)

# Configurar el tamaÃ±o de la figura
plt.figure(figsize=(cols * 6, rows * 4))

# Crear un boxplot para cada variable numÃ©rica
for i, var in enumerate(variables, 1):
    plt.subplot(rows, cols, i)
    sns.boxplot(x=df[var],  palette="RdPu")
    plt.title(f"Boxplot de {var.capitalize()}")
    plt.xlabel(var.capitalize())

# Ajustar el diseÃ±o para evitar solapamiento
plt.tight_layout()
plt.show()
# Out:
# C:\Users\aleja\AppData\Local\Temp\ipykernel_77152\1101586177.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df[var],  palette="RdPu")
# C:\Users\aleja\AppData\Local\Temp\ipykernel_77152\1101586177.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df[var],  palette="RdPu")
# C:\Users\aleja\AppData\Local\Temp\ipykernel_77152\1101586177.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df[var],  palette="RdPu")
# C:\Users\aleja\AppData\Local\Temp\ipykernel_77152\1101586177.py:19: FutureWarning:
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 1. GrÃ¡fico de barras para la distribuciÃ³n de suscripciones por ocupaciÃ³n (columna 'job')
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='job', hue='y', palette='RdPu')
plt.title('DistribuciÃ³n de suscripciones por ocupaciÃ³n')
plt.xlabel('OcupaciÃ³n')
plt.ylabel('NÃºmero de Suscripciones')
plt.xticks(rotation=45)
plt.legend(title='SuscripciÃ³n', labels=['No', 'SÃ­'])
plt.show()

# 3. GrÃ¡fico de distribuciÃ³n de edades
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='age', hue='y', kde=True, palette='RdPu')
plt.title('DistribuciÃ³n de Edades segÃºn SuscripciÃ³n')
plt.xlabel('Edad')
plt.ylabel('Frecuencia')
plt.legend(title='SuscripciÃ³n', labels=['No', 'SÃ­'])
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# SelecciÃ³n de las variables numÃ©ricas
numeric_vars = ['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous']

# Convertir la columna 'y' a valores numÃ©ricos (0 y 1)
df['y_numeric'] = df['y'].map({'No': 0, 'SÃ­': 1})

# Calcular la matriz de correlaciÃ³n entre las variables numÃ©ricas
correlacion = df[numeric_vars + ['y_numeric']].corr()

# Filtrar para mostrar solo la correlaciÃ³n con la variable 'y_numeric'
correlacion_interes = correlacion[['y_numeric']].drop('y_numeric')

# Crear un mapa de calor para visualizar la correlaciÃ³n
plt.figure(figsize=(10, 8))
sns.heatmap(correlacion_interes, annot=True, cmap='RdPu', fmt=".2f", linewidths=0.5, 
            cbar_kws={'label': 'CorrelaciÃ³n'})
plt.title('Matriz de CorrelaciÃ³n de Variables NumÃ©ricas del Cliente Bancario', 
          fontsize=14, fontweight='bold', family='Times New Roman')
plt.xticks(fontsize=10, family='Times New Roman')
plt.yticks(fontsize=10, family='Times New Roman')
plt.show()
